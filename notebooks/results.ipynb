# %% [markdown]
# # Results
# Run config: lr=0.01	epoch=10
# sklearn accuracy: 0.85780	keras accuracy: 0.60988
#
# Run config: lr=0.02	epoch=10
# sklearn accuracy: 0.85689	keras accuracy: 0.74617
#
# Run config: lr=0.04	epoch=10
# sklearn accuracy: 0.85137	keras accuracy: 0.73860
#
# Run config: lr=0.07	epoch=10
# sklearn accuracy: 0.85280	keras accuracy: 0.74612
#
# Run config: lr=0.14	epoch=10
# sklearn accuracy: 0.82837	keras accuracy: 0.76049
#
# Run config: lr=0.28	epoch=10
# sklearn accuracy: 0.81799	keras accuracy: 0.75097
#
# Run config: lr=0.54	epoch=10
# sklearn accuracy: 0.82927	keras accuracy: 0.73160
#
# Run config: lr=1.06	epoch=10
# sklearn accuracy: 0.80325	keras accuracy: 0.72960
#
# Run config: lr=2.06	epoch=10
# sklearn accuracy: 0.83299	keras accuracy: 0.70996
#
# Run config: lr=4.00	epoch=10
# sklearn accuracy: 0.82100	keras accuracy: 0.73009
#
# Run config: lr=0.01	epoch=20
# sklearn accuracy: 0.85816	keras accuracy: 0.78433
#
# Run config: lr=0.02	epoch=20
# sklearn accuracy: 0.85223	keras accuracy: 0.77307
#
# Run config: lr=0.04	epoch=20
# sklearn accuracy: 0.85582	keras accuracy: 0.72844
#
# Run config: lr=0.07	epoch=20
# sklearn accuracy: 0.84498	keras accuracy: 0.77520
#
# Run config: lr=0.14	epoch=20
# sklearn accuracy: 0.83714	keras accuracy: 0.75943
#
# Run config: lr=0.28	epoch=20
# sklearn accuracy: 0.83714	keras accuracy: 0.74959
#
# Run config: lr=0.54	epoch=20
# sklearn accuracy: 0.81274	keras accuracy: 0.74672
#
# Run config: lr=1.06	epoch=20
# sklearn accuracy: 0.83220	keras accuracy: 0.74179
#
# Run config: lr=2.06	epoch=20
# sklearn accuracy: 0.81901	keras accuracy: 0.76001
#
# Run config: lr=4.00	epoch=20
# sklearn accuracy: 0.81900	keras accuracy: 0.79712
#
# Run config: lr=0.01	epoch=30
# sklearn accuracy: 0.85710	keras accuracy: 0.76880
#
# Run config: lr=0.02	epoch=30
# sklearn accuracy: 0.85591	keras accuracy: 0.74280
#
# Run config: lr=0.04	epoch=30
# sklearn accuracy: 0.85493	keras accuracy: 0.75600
#
# Run config: lr=0.07	epoch=30
# sklearn accuracy: 0.84811	keras accuracy: 0.70899
#
# Run config: lr=0.14	epoch=30
# sklearn accuracy: 0.83886	keras accuracy: 0.72273
#
# Run config: lr=0.28	epoch=30
# sklearn accuracy: 0.82446	keras accuracy: 0.78700
#
# Run config: lr=0.54	epoch=30
# sklearn accuracy: 0.82397	keras accuracy: 0.77312
#
# Run config: lr=1.06	epoch=30
# sklearn accuracy: 0.81667	keras accuracy: 0.78639
#
# Run config: lr=2.06	epoch=30
# sklearn accuracy: 0.81513	keras accuracy: 0.79251
#
# Run config: lr=4.00	epoch=30
# sklearn accuracy: 0.83141	keras accuracy: 0.75602
#
# Run config: lr=0.01	epoch=40
# sklearn accuracy: 0.85880	keras accuracy: 0.73487
#
# Run config: lr=0.02	epoch=40
# sklearn accuracy: 0.85752	keras accuracy: 0.74396
#
# Run config: lr=0.04	epoch=40
# sklearn accuracy: 0.85372	keras accuracy: 0.72347
#
# Run config: lr=0.07	epoch=40
# sklearn accuracy: 0.84887	keras accuracy: 0.76021
#
# Run config: lr=0.14	epoch=40
# sklearn accuracy: 0.83857	keras accuracy: 0.76481
#
# Run config: lr=0.28	epoch=40
# sklearn accuracy: 0.84063	keras accuracy: 0.79045
#
# Run config: lr=0.54	epoch=40
# sklearn accuracy: 0.83365	keras accuracy: 0.75785
#
# Run config: lr=1.06	epoch=40
# sklearn accuracy: 0.80505	keras accuracy: 0.78802
#
# Run config: lr=2.06	epoch=40
# sklearn accuracy: 0.77960	keras accuracy: 0.68156
#
# Run config: lr=4.00	epoch=40
# sklearn accuracy: 0.77681	keras accuracy: 0.80101
#
# Run config: lr=0.01	epoch=50
# sklearn accuracy: 0.85723	keras accuracy: 0.78091
#
# Run config: lr=0.02	epoch=50
# sklearn accuracy: 0.85730	keras accuracy: 0.76883
#
# Run config: lr=0.04	epoch=50
# sklearn accuracy: 0.85486	keras accuracy: 0.73216
#
# Run config: lr=0.07	epoch=50
# sklearn accuracy: 0.84382	keras accuracy: 0.77308
#
# Run config: lr=0.14	epoch=50
# sklearn accuracy: 0.84035	keras accuracy: 0.79210
#
# Run config: lr=0.28	epoch=50
# sklearn accuracy: 0.81976	keras accuracy: 0.74814
#
# Run config: lr=0.54	epoch=50
# sklearn accuracy: 0.82941	keras accuracy: 0.78461
#
# Run config: lr=1.06	epoch=50
# sklearn accuracy: 0.77887	keras accuracy: 0.76938
#
# Run config: lr=2.06	epoch=50
# sklearn accuracy: 0.81387	keras accuracy: 0.80642
#
# Run config: lr=4.00	epoch=50
# sklearn accuracy: 0.80067	keras accuracy: 0.76306
#
# Run config: lr=0.01	epoch=60
# sklearn accuracy: 0.85877	keras accuracy: 0.79929
#
# Run config: lr=0.02	epoch=60
# sklearn accuracy: 0.85732	keras accuracy: 0.78558
#
# Run config: lr=0.04	epoch=60
# sklearn accuracy: 0.85279	keras accuracy: 0.77489
#
# Run config: lr=0.07	epoch=60
# sklearn accuracy: 0.85125	keras accuracy: 0.77733
#
# Run config: lr=0.14	epoch=60
# sklearn accuracy: 0.83467	keras accuracy: 0.77558
#
# Run config: lr=0.28	epoch=60
# sklearn accuracy: 0.83595	keras accuracy: 0.78135
#
# Run config: lr=0.54	epoch=60
# sklearn accuracy: 0.83591	keras accuracy: 0.78017
#
# Run config: lr=1.06	epoch=60
# sklearn accuracy: 0.82277	keras accuracy: 0.78483
#
# Run config: lr=2.06	epoch=60
# sklearn accuracy: 0.77760	keras accuracy: 0.76437
#
# Run config: lr=4.00	epoch=60
# sklearn accuracy: 0.74484	keras accuracy: 0.77284
#
# Run config: lr=0.01	epoch=70
# sklearn accuracy: 0.85761	keras accuracy: 0.77466
#
# Run config: lr=0.02	epoch=70
# sklearn accuracy: 0.85321	keras accuracy: 0.80585
#
# Run config: lr=0.04	epoch=70
# sklearn accuracy: 0.85628	keras accuracy: 0.78139
#
# Run config: lr=0.07	epoch=70
# sklearn accuracy: 0.85090	keras accuracy: 0.79537
#
# Run config: lr=0.14	epoch=70
# sklearn accuracy: 0.84014	keras accuracy: 0.82514
#
# Run config: lr=0.28	epoch=70
# sklearn accuracy: 0.83520	keras accuracy: 0.79383
#
# Run config: lr=0.54	epoch=70
# sklearn accuracy: 0.82268	keras accuracy: 0.78626
#
# Run config: lr=1.06	epoch=70
# sklearn accuracy: 0.81915	keras accuracy: 0.75913
#
# Run config: lr=2.06	epoch=70
# sklearn accuracy: 0.82170	keras accuracy: 0.77736
#
# Run config: lr=4.00	epoch=70
# sklearn accuracy: 0.79189	keras accuracy: 0.78745
#
# Run config: lr=0.01	epoch=80
# sklearn accuracy: 0.85887	keras accuracy: 0.77571
#
# Run config: lr=0.02	epoch=80
# sklearn accuracy: 0.85831	keras accuracy: 0.78059
#
# Run config: lr=0.04	epoch=80
# sklearn accuracy: 0.85297	keras accuracy: 0.77487
#
# Run config: lr=0.07	epoch=80
# sklearn accuracy: 0.85320	keras accuracy: 0.78056
#
# Run config: lr=0.14	epoch=80
# sklearn accuracy: 0.81145	keras accuracy: 0.78175
#
# Run config: lr=0.28	epoch=80
# sklearn accuracy: 0.80195	keras accuracy: 0.76534
#
# Run config: lr=0.54	epoch=80
# sklearn accuracy: 0.82769	keras accuracy: 0.77813
#
# Run config: lr=1.06	epoch=80
# sklearn accuracy: 0.83068	keras accuracy: 0.76822
#
# Run config: lr=2.06	epoch=80
# sklearn accuracy: 0.77066	keras accuracy: 0.78856
#
# Run config: lr=4.00	epoch=80
# sklearn accuracy: 0.80967	keras accuracy: 0.76006
#
# Run config: lr=0.01	epoch=90
# sklearn accuracy: 0.85823	keras accuracy: 0.78211
#
# Run config: lr=0.02	epoch=90
# sklearn accuracy: 0.85651	keras accuracy: 0.77480
#
# Run config: lr=0.04	epoch=90
# sklearn accuracy: 0.85640	keras accuracy: 0.77529
#
# Run config: lr=0.07	epoch=90
# sklearn accuracy: 0.83766	keras accuracy: 0.78192
#
# Run config: lr=0.14	epoch=90
# sklearn accuracy: 0.83970	keras accuracy: 0.77809
#
# Run config: lr=0.28	epoch=90
# sklearn accuracy: 0.80024	keras accuracy: 0.77451
#
# Run config: lr=0.54	epoch=90
# sklearn accuracy: 0.82949	keras accuracy: 0.79251
#
# Run config: lr=1.06	epoch=90
# sklearn accuracy: 0.77783	keras accuracy: 0.78209
#
# Run config: lr=2.06	epoch=90
# sklearn accuracy: 0.82768	keras accuracy: 0.78154
#
# Run config: lr=4.00	epoch=90
# sklearn accuracy: 0.77539	keras accuracy: 0.76968
